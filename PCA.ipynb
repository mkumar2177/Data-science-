# %% [markdown]
# # PCA
# -

# %%
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
pca =pd.read_csv("pca.csv")

# %%
pca.shape
# Out:
# (454, 8)

# %%
pca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454 entries, 0 to 453
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSSubClass    454 non-null    int64
#  1   LotArea       454 non-null    int64
#  2   OverallQual   454 non-null    int64
#  3   OverallCond   454 non-null    int64
#  4   TotalBsmtSF   454 non-null    int64
#  5   GrLivArea     454 non-null    int64
#  6   TotRmsAbvGrd  454 non-null    int64
#  7   SalePrice     454 non-null    int64
# dtypes: int64(8)
# memory usage: 28.5 KB

# %%
pca.describe()
# Out:
#        MSSubClass        LotArea  OverallQual  OverallCond  TotalBsmtSF  \
# count  454.000000     454.000000   454.000000   454.000000   454.000000
# mean    55.859031   11292.581498     6.138767     5.522026  1066.033040
# std     41.925641   15059.517516     1.345631     1.117076   418.859322
# min     20.000000    1596.000000     1.000000     1.000000     0.000000
# 25%     20.000000    7699.250000     5.000000     5.000000   796.500000
# 50%     50.000000    9434.500000     6.000000     5.000000  1023.000000
# 75%     60.000000   11612.000000     7.000000     6.000000  1313.000000
# max    190.000000  215245.000000    10.000000     9.000000  3206.000000
#
#          GrLivArea  TotRmsAbvGrd      SalePrice
# count   454.000000    454.000000     454.000000
# mean   1520.099119      6.508811  182283.894273
# std     497.564715      1.533629   77454.944643
# min     520.000000      3.000000   40000.000000
# 25%    1153.500000      5.000000  128050.000000
# 50%    1463.000000      6.000000  165800.000000
# 75%    1772.500000      7.000000  218875.000000
# max    3608.000000     12.000000  555000.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 pca = pca_iris()
#
# NameError: name 'pca_iris' is not defined

# %%
X = pca.data
y = pca.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17576\580622015.py in ?()
# ----> 1 X = pca.data
#       2 y = pca.target
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'
