# %% [markdown]
# # Decision tree
# ## 1. Entropy(
#  - measure the randomness
#  - range(0-1)
#  - sum([ilog2(pi))
# ## 2. Information Gain
# - ig=entropy of parent - entropy of chld
# - Higher IG =bettter split
# ## 3. Gini index
# -use to meausure empurity of data
# Gini = 1-SUMpi^2
# pure node=0
# maximum impurity =0.5(binary)
# lower Gini =better split
#
# # cart
#   gini minimum

# %%
import pandas as pd

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

from sklearn import tree

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Salary_dataset.csv")

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x=df[['YearsExperience']]
y=df['Salary']

# %%
X_train , X_test , y_train, y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
dt=DecisionTreeRegressor() #mae ,mse

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(X_test)

# %%
dt.score(X_train, y_train)
# Out:
# 0.9999631319936537

# %%
plt.figure(figsize=(24,10))
tree.plot_tree(
    dt,
    filled=True,
    feature_names=x.columns
)
plt.show()

# %%
import pickle

best_model = grid_search.best_estimator_

with open("decision_tree_model.pkl", "wb") as file:
    pickle.dump(best_model, file)

print("Best model saved successfully!")
# Out:
# Best model saved successfully!

# %% [markdown]
# # Random  Forest
#  ## 1. Bagging
#  ## 2. Boosting

# %%
#ye accuracy bdhane k liye use hota h ,if model ka accuracy achi nh ih then use krna h 



from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %%
param = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
    'max_depth': [2, 3, 4, 5, 6, 7, 8, 10, None],
    'min_samples_split': [2, 3, 5, 10],
    'min_samples_leaf': [1, 2, 4, 6],
    'max_features': [None, 'sqrt', 'log2']
}

# %%
grid_search = GridSearchCV(
    estimator=DecisionTreeRegressor(random_state=42),
    param_grid=param,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [2, 3, 4, 5, 6, 7, 8, 10, None],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4, 6],
#                          'min_samples_split': [2, 3, 5, 10]},
#              scoring='r2')

# %%
print("Best Parameters:")
print(grid_search.best_params_)
# Out:
# Best Parameters:
# {'criterion': 'absolute_error', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
print("\nBest CV Score:")
print(grid_search.best_score_)
# Out:
# Best CV Score:
# 0.9217939825076543

# %% [markdown]
# # decision tree classficaion
