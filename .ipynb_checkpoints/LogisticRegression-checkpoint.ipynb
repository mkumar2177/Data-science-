# %% [markdown]
# # Logistic  Regression

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    SNo       X_1       X_2   y
# 0    0 -0.869144  0.389310  0.0
# 1    1 -0.993467 -0.610591  0.0
# 2    2 -0.834064  0.239236  0.0
# 3    3 -0.136471  0.632003  1.0
# 4    4  0.403887  0.310784  1.0

# %%
df.isnull().sum()
# Out:
# SNo    0
# X_1    0
# X_2    0
# y      0
# dtype: int64

# %%
df.tail()
# Out:
#     SNo       X_1       X_2   y
# 95   95  0.531635 -0.479185  1.0
# 96   96 -0.650192  0.655303  1.0
# 97   97  0.985299  0.118333  1.0
# 98   98 -0.275289  0.005730  1.0
# 99   99  0.281860  0.726376  1.0

# %%
df.shape
# Out:
# (100, 4)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#     SNo       X_1       X_2
# 0     0 -0.869144  0.389310
# 1     1 -0.993467 -0.610591
# 2     2 -0.834064  0.239236
# 3     3 -0.136471  0.632003
# 4     4  0.403887  0.310784
# ..  ...       ...       ...
# 95   95  0.531635 -0.479185
# 96   96 -0.650192  0.655303
# 97   97  0.985299  0.118333
# 98   98 -0.275289  0.005730
# 99   99  0.281860  0.726376
#
# [100 rows x 3 columns]

# %%
y
# Out:
# 0     0.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     1.0
#      ...
# 95    1.0
# 96    1.0
# 97    1.0
# 98    1.0
# 99    1.0
# Name: y , Length: 100, dtype: float64

# %%
x
# Out:
#         x
# 0    24.0
# 1    50.0
# 2    15.0
# 3    38.0
# 4    87.0
# ..    ...
# 695  58.0
# 696  93.0
# 697  82.0
# 698  66.0
# 699  97.0
#
# [700 rows x 1 columns]
