# %% [markdown]
# # string in python

# %%
name="khalid"
city='delhi'
print(name)
print(city)
# Out:
# khalid
# delhi

# %%
#string in triple quotes
name='''khalid'''
print(name)
# Out:
# khalid

# %%
name='khalid umar'
course="Btech IT"
info='''
college:adgips
sem=3rd
Goal:data scientist
'''
print(f"Name : {name}\nCourse:{course}\n{info}")
# Out:
# Name : khalid umar
# Course:Btech IT
#
# college:adgips
# sem=3rd
# Goal:data scientist

# %% [markdown]
# # variable

# %%
a="hello"
print(a)
# Out:
# hello

# %%
#all arithmetic optr
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100000000000000000000
# 0
# False
# True
# False
# True

# %%
name="umar"
age=21
height=5.7
print(type(name))
print(type(age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
price = input("Enter your price: ")
print(f"Name: {name}\nAge: {age}\nPrice: {price}")
print(type(name))
print(type(age))
print(type(price))
# Out:
# Enter your name:  umar
# Enter your age:  21
# Enter your price:  5.7
# Name: umar
# Age: 21
# Price: 5.7
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
price=input("enter your price: ")
print(f"Name: {name}\nAge: {age}\nPrice: {price}")
print(type(name))
print(type(age))
print(type(price))
# Out:
# Enter your name:  umar
# Enter your age:  21
# enter your price:  5.6
# Name: umar
# Age: 21
# Price: 5.6
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
#  Create a real calculator using python that can perform addition, subtraction, multiplication, division, modulus, exponentiation, floor division and also compare two numbers.
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter your choice: 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division, 5 for modulus, 6 for exponentiation, 7 for floor division, 8 for comparison: "))
if c==1:
    print(f"Addition of {a} and {b} is: {a+b}")
elif c==2:
    print(f"Subtraction of {a} and {b} is: {a-b}")
elif c==3:
    print(f"Multiplication of {a} and {b} is: {a*b}")
elif c==4:
    print(f"Division of {a} and {b} is: {a/b}")
elif c==5:
    print(f"Modulus of {a} and {b} is: {a%b}")
elif c==6:
    print(f"Exponentiation of {a} and {b} is: {a**b}")
elif c==7:
    print(f"Floor division of {a} and {b} is: {a//b}")
elif c==8:
    if a>b:
        print(f"{a} is greater than {b}")
    elif a<b:
        print(f"{a} is less than {b}")
    else:
        print(f"{a} is equal to {b}")
# Out:
# Enter first number:  2
# Enter second number:  3
# Enter your choice: 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division, 5 for modulus, 6 for exponentiation, 7 for floor division, 8 for comparison:  5
# Modulus of 2 and 3 is: 2
