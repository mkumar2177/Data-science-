# %%
import numpy as np

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as mp

img = Image.open("download (16).jpg")
img = np.array(img)
img[:,:,0] = np.clip(img[:,:,0] + 0, 255, 255)   # Line 6
img = np.rot90(img)
mp.imshow(img)
mp.axis("OFF")
mp.show()

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as mp

img = Image.open("download (16).jpg")
img = np.array(img)

h, w, c = img.shape

mid_h = h // 2
mid_w = w // 2

img[0:mid_h, 0:mid_w, 0] = np.clip(
    img[0:mid_h, 0:mid_w, 0] + 100, 0, 255)

img[0:mid_h, mid_w:w, 1] = np.clip(
    img[0:mid_h, mid_w:w, 1] + 100, 0, 255)

img[mid_h:h, 0:mid_w, 2] = np.clip(
    img[mid_h:h, 0:mid_w, 2] + 100, 0, 255)

img[mid_h:h, mid_w:w, 0] = np.clip(
    img[mid_h:h, mid_w:w, 0] + 100, 0, 255)

img[mid_h:h, mid_w:w, 1] = np.clip(
    img[mid_h:h, mid_w:w, 1] + 100, 0, 255)

# Show image
mp.imshow(img)
mp.axis("OFF")
mp.show()

# %% [markdown]
# # Pandas

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.DataFrame({"Name":["umar","khalid","sharmeen","vikram"],"Marks":[20,30,40,40]})
df
# Out:
#        Name  Marks
# 0      umar     20
# 1    khalid     30
# 2  sharmeen     40
# 3    vikram     40

# %%
df.duplicated("Marks")
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   32.500000
# std     9.574271
# min    20.000000
# 25%    27.500000
# 50%    35.000000
# 75%    40.000000
# max    40.000000
