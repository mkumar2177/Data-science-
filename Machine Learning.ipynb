# %% [markdown]
# # MACHINE LEARNING

# %%
#algorithm to make ml project

# %%
step 1=import all libraries

# %%
step 2=import dataset using pandas (pd.read_CSV,...)

# %%
step 3=eda or processing pur dataset

# %%
step 4=target variables select(xx,y(x is input data , y is output data))

# %%
step 5=data divide into two parts - Training,Testing(x,y both)

# %%
step 6= impot model (lr=linerregression)

# %%
step 7=training data will be fitt on model(lr.fit(X_train,Y_train)

# %%
step 8=Make prediction (lr.predict(x_test))

# %%
step 9=check model evaluation matricse (r2 score ,mse ,mae ,flscore,prescision,rexall accuracy score)

# %%
step 10= convert model into pkl file and then we will make gui and maek prediction using frontend)
